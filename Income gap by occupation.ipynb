# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('inc_occ_gender.csv')

# %%
df
# Out:
#                                     Occupation  All_workers All_weekly  \
# 0                              ALL OCCUPATIONS       109080        809
# 1                                   MANAGEMENT        12480       1351
# 2                             Chief executives         1046       2041
# 3              General and operations managers          823       1260
# 4                                  Legislators            8         Na
# ..                                         ...          ...        ...
# 553                  Pumping station operators           18         Na
# 554  Refuse and recyclable material collectors           72        501
# 555                 Mine shuttle car operators            0         Na
# 556          Tank car, truck, and ship loaders            6         Na
# 557         Material moving workers, all other           37         Na
#
#      M_workers M_weekly  F_workers F_weekly
# 0        60746      895      48334      726
# ...

# %%
df_new = df[df.All_weekly != 'Na']

# %%
df_new.shape
# Out:
# (322, 7)

# %%
df_new = df[df.M_weekly != 'Na']

# %%
df_new = df[df.F_weekly != 'Na']

# %%
df_new.shape
# Out:
# (192, 7)

# %%
df_new
# Out:
#                                             Occupation  All_workers  \
# 0                                      ALL OCCUPATIONS       109080
# 1                                           MANAGEMENT        12480
# 2                                     Chief executives         1046
# 3                      General and operations managers          823
# 6                         Marketing and sales managers          948
# ..                                                 ...          ...
# 521                                     TRANSPORTATION         6953
# 527                                        Bus drivers          323
# 528             Driver/sales workers and truck drivers         2687
# 550  Laborers and freight, stock, and material move...         1433
# 552                        Packers and packagers, hand          385
#
#     All_weekly  M_workers M_weekly  F_workers F_weekly
# 0          809      60746      895      48334      726
# ...

# %% [markdown]
# Now to clean and combine this data.
